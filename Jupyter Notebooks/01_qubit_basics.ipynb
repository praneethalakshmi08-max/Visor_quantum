# %% [markdown]
# ## Qubit Basics
#
# ## 1. Objective:
#
# Learn the difference between classical bits and quantum bits (qubits), and understand how qubits represent information.
#
# - Explain the difference between classical bits and qubits.
#
# - Understand the concept of quantum superposition.
#
# - Identify computational basis states.
#
# - Creates a simple one-qubit quantum circuit using Qiskit.

# %% [markdown]
# ## 2. Introduction
#
# A classical computer stores information using bits, which can only have one of two values:
#
# - 0
#
# - 1
#
# a quantum computer stores information using qubits. Unlike classical bits, qubits can exist in a superposition, meaning they can represent both 0 and 1 simultaneously until they are measured.

# %% [markdown]
# ## 3. Classical Bit Vs Qubit
#
#
# | Classical Bit | Quantum Bit (Qubit) |
# |---------------|---------------------|
# | 0 or 1 | α\|0⟩ + β\|1⟩ |
# | Deterministic | Probabilistic |
# | No Superposition | Supports Superposition |
# | No Entanglement | Can Be Entangled |

# %% [markdown]
# ## 4. Computational Basis States
#
#
# The two basic quantum states are:
#
# |0> and |1>
#
# The computational basis states are represented as vectors:
#
# |0> = [1]
#       [0]
#
#
#
# |1> = [0] [1]

# %% [markdown]
# ## 5. Example Using Qiskit
#
# The following code creates a quantum circuit with one qubit and displays its circuit diagram.

# %%
# !pip install qiskit

# %% [markdown]
# ## Output
#
# Collecting qiskit
# -  Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# - Requirement already satisfied: numpy<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# - Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# - Collecting rustworkx>=0.15.0 (from qiskit)
#   - Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.- manylinux_2_17_x86_64.whl.metadata (10 kB)
# - Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# - Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# - Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# - Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 21.3 MB/s eta 0:00:00
# - Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 89.3 MB/s eta 0:00:00
# - Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.7 MB/s eta 0:00:00
# - Installing collected packages: stevedore, rustworkx, qiskit
# - Successfully installed qiskit-2.5.0 rustworkx-0.18.0 stevedore-5.9.0

# %%
from qiskit import QuantumCircuit
# Create a quantum circuit with one qubit
qc= QuantumCircuit(1)
# Draw the circuit
print(qc.draw())

# %% [markdown]
# ## Output
#
#
# q:

# %% [markdown]
# ## 6. Knowledge check
#
# ## Question 1
#
# How many states can a classical bit represent?
#
# A) Infinite
#
# B) Two
#
# C) Four
#
# D) Eight
#
# **Answer:** B
#
#
#
# ## Question 2
#
# Which quantum phenoenon allows a qubit to exist in multiple states simultaneously?
#
# A) Measurement
#
# B) superposition
#
# C) Entanglement
#
# D) Teleportation
#
# **Answer:** B

# %% [markdown]
# ## 7. Real-World Applications
#
# Qubits are the foundations of quantum computing and are used in:
#
# - Quantum Cryptography
#
# - Drug Discovery
#
# - Optimization Problems
#
# - Artificial Intelligence
#
# - Financial Modelling

# %% [markdown]
# ## Next Topic
#
# Now that you understand qubits, continue with:
#
# -> Understand Quantum Gates

# %% [markdown]
# ## 8. Applying Basic Quantum Gates
#
# ## X Gate (Bit Flip)
#
# The X gate flips the state of a qubit.
#
# |0> -> |1>
#
# |1> -> |0>

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)

qc.x(0)

print(qc.draw())

# %% [markdown]
# ## Output
#
# ```text
#    ┌───┐
# q: ┤ X ├
#    └───┘
#
# ```

# %% [markdown]
# Explanation:
#
# The X gate behaves like a classical NOT gate by flipping the qubit from |0> to |1>.

# %% [markdown]
# ## 9. Hadamard (H) Gate
#
# The Hadamard gate creates a superposition.

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)

qc.h(0)

print(qc.draw())

# %% [markdown]
# ## Output
#
# ``` text
#
#    ┌───┐
# q: ┤ H ├
#    └───┘
#
# ```

# %% [markdown]
# Explanation:
#
# The H gate transforms the qubit into superposition state, allowing it to have probabilities of being measured as both |0> and |1>.

# %% [markdown]
# ## 10. Z Gate (phase flip)
#
# |0> -> |0>
#
# |1> -> |-1>

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)

qc.z(0)

print(qc.draw())

# %% [markdown]
# ## Output
#
# ```text
#    ┌───┐
# q: ┤ Z ├
#    └───┘
# ```

# %% [markdown]
# Explanation:
#
# The Z gate changes the phase of the |1> component without changing the measurement probabilities.

# %% [markdown]
# ## 11. Y Gate

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)

qc.y(0)

print(qc.draw())

# %% [markdown]
# ## Output
#
# ```text
#
#    ┌───┐
# q: ┤ Y ├
#    └───┘

# %% [markdown]
# Explanation:
#
# The Y gate combines a bit flip and a phase flip

# %% [markdown]
# ## 12. Applying Multiple Gates

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)

qc.h(0)
qc.z(0)
qc.x(0)

print(qc.draw())

# %% [markdown]
# ## Output
#
# ```text
#
#    ┌───┐┌───┐┌───┐
# q: ┤ H ├┤ Z ├┤ X ├
#    └───┘└───┘└───┘
